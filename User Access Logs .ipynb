# %%
import pandas as pd 

employees_df= pd.read_csv('data/employees.csv')
system_access_df= pd.read_csv('data/system_access.csv')


df = employees_df.join(system_access_df, how='left')
df.head(25)
# Out:
#    employee_number first_name  last_name                             email  \
# 0        EMP003037    Juliana   Burbudge  juliana.burbudge@consultants.com
# 1        EMP003045     Lizzie       Blue       lizzie.blue@consultants.com
# 2        EMP003051    Marjory   Selcraig  marjory.selcraig@consultants.com
# 3        EMP003068     Aguste   O'Connor   aguste.o'connor@consultants.com
# 4        EMP003097    Clemens     Kopman    clemens.kopman@consultants.com
# 5        EMP003133   Donielle    Midgley  donielle.midgley@consultants.com
# 6        EMP003134    Marcela     Thieme    marcela.thieme@consultants.com
# 7        EMP003180      Haily    Wadeson     haily.wadeson@consultants.com
# 8        EMP003265     Natala       Judd       natala.judd@consultants.com
# 9        EMP003287      Gayla      Aldin       gayla.aldin@consultants.com
# 10       EMP003291    Gweneth     Abbate    gweneth.abbate@consultants.com
# ...

# %%
system_access_df.rename(columns={'id': 'employee_number'}, inplace=True)

# %%
system_access_df['employee_number'] = 'EMP'+ system_access_df['employee_number'].astype(str).str.zfill(6)
system_access_df
# Out:
#     employee_number        access_level
# 0         EMP017263       Account Admin
# 1         EMP010275      Contract Entry
# 2         EMP007568      Contract Entry
# 3         EMP021986       Account Admin
# 4         EMP020614       Account Admin
# ..              ...                 ...
# 849       EMP007600      Contract Entry
# 850       EMP011112  Approval - Manager
# 851       EMP005295      Contract Entry
# 852       EMP007470       Account Admin
# 853       EMP016383      Contract Entry
#
# [854 rows x 2 columns]

# %%
df_missingAL= df.loc[df['access_level'].isnull()]
df_missingAL
# Out:
#      employee_number  first_name    last_name  \
# 854        EMP020143     Nerissa       Drogan
# 855        EMP020160     Ichabod     Schultze
# 856        EMP020166    Bethanne        Shugg
# 857        EMP020287       Halsy       Mounch
# 858        EMP020288      Aurlie  MacTerrelly
# ...              ...         ...          ...
# 1115       EMP024864    Kristina        Yakov
# 1116       EMP024885   Margarita   Habbergham
# 1117       EMP024890    Prescott    Southward
# 1118       EMP024896       Raine      Learned
# 1119       EMP024931  Frederique         Fant
#
#                                      email            title  id access_level
# 854         nerissa.drogan@consultants.com  Sales Assistant NaN          NaN
# 855       ichabod.schultze@consultants.com  Sales Assistant NaN          NaN
# 856         bethanne.shugg@consultants.com  Account Manager NaN          NaN
# 857           halsy.mounch@consultants.com  Account Manager NaN          NaN
# ...

# %%
df.loc[df['access_level'].notnull()]
# Out:
#     employee_number  first_name last_name                             email  \
# 0         EMP003037     Juliana  Burbudge  juliana.burbudge@consultants.com
# 1         EMP003045      Lizzie      Blue       lizzie.blue@consultants.com
# 2         EMP003051     Marjory  Selcraig  marjory.selcraig@consultants.com
# 3         EMP003068      Aguste  O'Connor   aguste.o'connor@consultants.com
# 4         EMP003097     Clemens    Kopman    clemens.kopman@consultants.com
# ..              ...         ...       ...                               ...
# 849       EMP020103  Jackquelin      Mose   jackquelin.mose@consultants.com
# 850       EMP020105       Reena   Goreway     reena.goreway@consultants.com
# 851       EMP020106      Evered  Scollick   evered.scollick@consultants.com
# 852       EMP020108     Chrissy   McIntee   chrissy.mcintee@consultants.com
# 853       EMP020131       Selma    Storek      selma.storek@consultants.com
#
#                  title       id        access_level
# ...

# %%
system_access_df
# Out:
#      employee_number        access_level
# 0              17263       Account Admin
# 1              10275      Contract Entry
# 2               7568      Contract Entry
# 3              21986       Account Admin
# 4              20614       Account Admin
# ..               ...                 ...
# 849             7600      Contract Entry
# 850            11112  Approval - Manager
# 851             5295      Contract Entry
# 852             7470       Account Admin
# 853            16383      Contract Entry
#
# [854 rows x 2 columns]

# %%
print(len(df))
# Out:
# 1120

# %%
subset_df = df.loc[df['system_access'].isnull()].copy()
print(len(subset_df))
subset_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'system_access'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-ee7bbc3af297> in <module>
# ...

# %%
 subset_df.loc[subset_df ['title'] == 'Director of Sales', 'access_level'] = 'Data Mining'

subset_df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-aac361126014> in <module>
# ----> 1 subset_df.loc[subset_df ['title'] == 'Director of Sales', 'access_level'] = 'Data Mining'
#       2
#       3 subset_df.tail()
#
# AttributeError: 'str' object has no attribute 'loc'
